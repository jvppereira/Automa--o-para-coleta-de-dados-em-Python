# %%
#//*[@id="root"]/div/div/div/table/tbody/tr/td[3] xpath
from selenium import webdriver
import time 
from selenium.webdriver.common.by import By
import pandas
import csv
navegador = webdriver.Chrome()

navegador.get('https://npdeas3t.vercel.app/User')



#login na pagina

time.sleep(4) 
titulo = navegador.find_element(By.XPATH, '//*[@id="root"]/div/nav/ul/li[1]/a').click()
print(titulo)

time.sleep(2) 
nome = navegador.find_element(By.XPATH, '//*[@id="root"]/div/div/div/form/label[1]/input').send_keys('npdeas3t@gmail.com')
nome

senha = navegador.find_element(By.XPATH, '//*[@id="root"]/div/div/div/form/label[2]/input').send_keys('npdeas3tadmin2020')


time.sleep(1) 

log = navegador.find_element(By.XPATH, '//*[@id="root"]/div/div/div/form/button').click()
time.sleep(2) 

user = navegador.find_element(By.XPATH, '//*[@id="root"]/div/nav/ul/li[5]/a').click()

time.sleep(2) 
btn = navegador.find_element(By.XPATH, '//*[@id="root"]/div/div/div/form/button').click()


time.sleep(1) 

#coleta de dados

nomelista = []
cpflista = []
emaillista = []
teamlista = []
goallista = []
categorylista = []
subcategorylista = []
courselista = []
UIDlista = []
    

for i in range(1,4):                     
    cpf = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{1}]').text
    nome = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{2}]').text
    email = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{3}]').text
    team = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{4}]').text
    goal = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{5}]').text
    category = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{6}]').text
    course = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{7}]').text
    subcategory = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{8}]').text
    #UID = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{9}]').text
    
    cpflista.append(cpf)
    nomelista.append(nome)
    emaillista.append(email)
    teamlista.append(team)
    goallista.append(goal)
    categorylista.append(category)
    courselista.append(course)
    subcategorylista.append(subcategory)
    #UIDlista.append(UID)
      

planilha = zip(nomelista, cpflista, emaillista, teamlista, goallista, categorylista, courselista, subcategorylista)
planilha2 = list(planilha)


import csv
#transformando 
fields = ['cpf', 'nome', 'email', 'team', 'goal', 'category', 'course', 'subcategory']

import pandas as pd
from openpyxl import Workbook, load_workbook

k = len(planilha2)
itens = []
for x in range(1,k+1):
    c = str(x)
    itens.append(c)

f = zip(itens, planilha2)
nvendas = dict(f)

nvendas_df = pd.DataFrame.from_dict(nvendas, orient='index')
nvendas_df = nvendas_df.rename(columns={0: 'cpf',1: 'nome',2: 'email',3: 'team',4: 'goal',5: 'category',6: 'course',7: 'subcategory'})
nvendas_df.to_csv(r'planilha1.csv', sep=';') #criou o arquivo para ser aberto 
display(nvendas_df) 

#abrindo o day
time.sleep(1) 

day = navegador.find_element(By.XPATH, '//*[@id="root"]/div/nav/ul/li[1]/a').click()
time.sleep(2) 

refresh = navegador.find_element(By.XPATH, '//*[@id="root"]/div/div/div/form/button').click()

time.sleep(1) 

#coleta de dados 2

nomelista = []
daylista = []
weeklista = []
monthlista = []
goallista = []
teamlista = []


for i in range(1,4):                     
    nome = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{1}]').text
    day = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{3}]').text
    week = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{4}]').text
    month = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{5}]').text
    goal = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{6}]').text
    team = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{7}]').text
    #UID = navegador.find_element(By.XPATH, f'//*[@id="root"]/div/div/div/table/tbody[{i}]/tr/td[{9}]').text
    
    nomelista.append(nome)
    daylista.append(day)
    weeklista.append(week)
    monthlista.append(month)
    goallista.append(goal)
    teamlista.append(team)
   


    

planilha = zip(nomelista, daylista, weeklista, monthlista, goallista, teamlista)
planilha3 = list(planilha)


#transformando os dados em dicionarios para poder mexer em csv
fields = ['nome', 'day', 'week', 'month', 'goal', 'team']



k = len(planilha3)
itens = []
for x in range(1,k+1):
    c = str(x)
    itens.append(c)

f = zip(itens, planilha3)
nvendas = dict(f)

nvendas_df = pd.DataFrame.from_dict(nvendas, orient='index')
nvendas_df = nvendas_df.rename(columns={0: 'nome', 1: 'day', 2: 'week',3: 'month',4: 'goal',5: 'team'})
nvendas_df.to_csv(r'planilha2.csv', sep=';') #criou o arquivo para ser aberto 
display(nvendas_df)
# Out:
# None
#            cpf                     nome                      email  \
# 1  04445663921  Erick Cordeiro Kollross      erickkollross@ufpr.br
# 2  14401214943       João Vitor Pereira      jvppereira1@gmail.com
# 3  52750513871             Otávio Burch  otavioburch2004@gmail.com
#
#              team goal category     course                  subcategory
# 1         C-Level  12h    aluno        pós  Engenharia ágil de projetos
# 2          Lumens  12h    aluno  graduação         Gestão da informação
# 3  Startup Lumens  12h    aluno  graduação         Gestão da Informação
#                       nome     day    week   month goal            team
# 1  Erick Cordeiro Kollross  00:00h  03:01h  05:45h  12h         C-Level
# 2       João Vitor Pereira  00:00h  02:25h  05:03h  12h          Lumens
# 3             Otávio Burch  00:00h  03:12h  03:12h  12h  Startup Lumens
